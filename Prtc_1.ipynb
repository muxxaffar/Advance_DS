# %%
import pandas as pd
import numpy as np

s = pd.Series(["welocome ","to","data 100"])

# %%
s
# Out:
# 0    welocome
# 1           to
# 2     data 100
# dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.values
# Out:
# array(['welocome ', 'to', 'data 100'], dtype=object)

# %% [markdown]
# **We can provide index labels for items in a Series by passing an index list.**

# %%
ab = pd.Series([-1,10,2], index = ["a","b","c"])
ab
# Out:
# a    -1
# b    10
# c     2
# dtype: int64

# %%
ab.index = ["first","second","third"]
ab
# Out:
# first     -1
# second    10
# third      2
# dtype: int64

# %%
fb = pd.Series([4,-2,0,6], index = ["a","b","c","d"])
fb
# Out:
# a    4
# b   -2
# c    0
# d    6
# dtype: int64

# %%
fb["d"] ,
fb["a"]
# Out:
# 4

# %%
#List of Lable 
fb[["c","d"]]
# Out:
# c    0
# d    6
# dtype: int64

# %%
#A Filtering Condition 

fb > 0
# Out:
# a     True
# b    False
# c    False
# d     True
# dtype: bool

# %%
fb < 0
# Out:
# a    False
# b     True
# c    False
# d    False
# dtype: bool
